# %%
from funciones import calculate_weighted_returns, calculate_and_store_returns, plot_line_graphs, load_and_process_excel, plot_pie_chart

# %%
SB, SB_inv = load_and_process_excel('SB 55-59','WEB_SB 55-59')

# %% [markdown]
# Ahora calcularemos el promedio del retorno segun Cálculo conforme a las DISPOSICIONES de Carácter General  que establecen el procedimiento para la construcción de los indicadores de rendimiento neto de las sociedades de inversión especializadas de fondos para el retiro publicadas en el DOF el 2 de junio de 2022 y sus posteriores modificaciones.
#
# Link: https://www.dof.gob.mx/nota_detalle.php?codigo=5653931&fecha=02/06/2022#gsc.tab=0

# %%
p = [0.2, 0.3, 0.5]
n = [3, 5, 10]
promedio_retornos = calculate_weighted_returns(SB, p, n)

# Encuentra la fila con el valor más alto en 'Weighted Average Return'
fila_superior = promedio_retornos.sort_values(by='Weighted Average Return', ascending=False).iloc[0]

# Extrae el nombre y el valor
nombre = fila_superior['Siefore']
valor_alto = fila_superior['Weighted Average Return']

print(f"El siefore: {nombre}, tiene el rendimiento más alto: {valor_alto}")
promedio_retornos
# Out:
# El siefore: Inbursa (SB 55-59), tiene el rendimiento más alto: 5.87
#                     Siefore  Weighted Average Return
# 0         Azteca (SB 55-59)                     5.31
# 1    Citibanamex (SB 55-59)                     4.39
# 2         Coppel (SB 55-59)                     4.90
# 3        Inbursa (SB 55-59)                     5.87
# 4       Invercap (SB 55-59)                     4.77
# 5  PensionISSSTE (SB 55-59)                     5.69
# 6      Principal (SB 55-59)                     5.25
# 7      Profuturo (SB 55-59)                     4.97
# 8           SURA (SB 55-59)                     5.23
# 9    XXI-Banorte (SB 55-59)                     4.98

# %% [markdown]
# Para generar una imagen que ilustre la diversificación de las inversiones de las AFORES, veremos tres gráficos. El primero muestra las inversiones generales de un AFORE, con sectores variados y coloridos para representar diferentes tipos de inversiones. Los otros dos gráficos se centran en inversiones específicas: uno para inversiones gubernamentales y otro para inversiones privadas nacionales. Estos dos gráficos tienen detalles y anotaciones específicos para destacar características particulares de estas inversiones, como sectores de interés o tendencias de crecimiento. El contraste entre el gráfico general y los dos específicos resalta la diversidad y especificidad de las inversiones de las AFORES.

# %%
for siefore in SB_inv.columns:
    plot_pie_chart(SB_inv,siefore)
    print('\n')

# %% [markdown]
# Vemos que la mayoria invierte en Gubernamental, lo cual tiene sentido porque es una inversion segura, no de alto rendimiento, pero lo que buscamos en esta generacion es asegurarnos en acumular lo maximo posible sin mucho riesgo de perder en el camino, por lo cual las inversiones a Gobierno son las ideales

# %% [markdown]
# ### Rendimiento a traves del tiempo

# %% [markdown]
# Para crear una imagen que represente el movimiento de los retornos a lo largo del tiempo para cada AFORE en los distintos años utilizados para calcular el indicador de rendimiento neto, visualiza una serie de gráficos de líneas. Cada línea representa un AÑO diferente, trazando su rendimiento a lo largo de varios meses. Los colores de las líneas varían para distinguir claramente cada AÑO. Estos gráficos mostrarán tendencias, picos y valles, ilustrando cómo han fluctuado los rendimientos en diferentes épocas.
#
#
# ### NOTA: rendimientos pasados no garantizan rendimientos futuros

# %%
siefores_returns_dict = calculate_and_store_returns(SB)
plot_line_graphs(siefores_returns_dict)
